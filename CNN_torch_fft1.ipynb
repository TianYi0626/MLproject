# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from utils import one_hot_to_index, filter_data_for_X, transform_labels_model, to_one_hot, save_filtered_data
from sklearn.preprocessing import StandardScaler
import numpy as np

scaler = StandardScaler()
# Load the data from L1_8000rpm_data/ folder
X_train = pd.read_csv('8000rpm_data_z-score/train_sample_fft_scaled.csv')
X_test = pd.read_csv('8000rpm_data_z-score/test_sample_fft_scaled.csv')
y_train = pd.read_csv('8000rpm_data_z-score/train_label.csv')
y_test = pd.read_csv('8000rpm_data_z-score/test_label.csv')

# %%
# Apply the one-hot to index conversion
y_train_model = one_hot_to_index(y_train)
y_test_model = one_hot_to_index(y_test)

y_train_model = transform_labels_model(y_train_model, [1, 2, 3, 4, 5, 6, 7, 8, 9], [1, 1, 1, 2, 2, 2, 3, 3, 3])
y_test_model = transform_labels_model(y_test_model, [1, 2, 3, 4, 5, 6, 7, 8, 9], [1, 1, 1, 2, 2, 2, 3, 3, 3])

# Apply one-hot encoding to the labels for Model 2
y_train_model_onehot = to_one_hot(y_train_model, num_classes=3)
y_test_model_onehot = to_one_hot(y_test_model, num_classes=3)

save_filtered_data(
    X_train, y_train_model_onehot, 
    'data1/train_sample_model.csv', 
    'data1/train_label_model.csv')
save_filtered_data(
    X_test, y_test_model_onehot, 
    'data1/test_sample_model.csv', 
    'data1/test_label_model.csv')

# %%
# Apply the one-hot to index conversion
y_train = one_hot_to_index(y_train)
y_test = one_hot_to_index(y_test)

# Apply the filter to the train and test sets
X_train_model1, y_train_model1 = filter_data_for_X(y_train, X_train, [1, 2, 3])
X_test_model1, y_test_model1 = filter_data_for_X(y_test, X_test, [1, 2, 3])
X_train_scaled1 = np.apply_along_axis(
    lambda row: scaler.fit_transform(row.reshape(-1, 1)).flatten(), axis=1, arr=X_train_model1)
X_test_scaled1 = np.apply_along_axis(
    lambda row: scaler.fit_transform(row.reshape(-1, 1)).flatten(), axis=1, arr=X_test_model1)
# Apply the transformation to the labels
# y_train_model1 = transform_labels_model(y_train_model1)
# y_test_model1 = transform_labels_model(y_test_model1)

# Apply one-hot encoding to the labels for Model 2
y_train_model1_onehot = to_one_hot(y_train_model1, num_classes=3)
y_test_model1_onehot = to_one_hot(y_test_model1, num_classes=3)

save_filtered_data(
    X_train_scaled1, y_train_model1_onehot, 
    'data1/train_sample_model1.csv', 
    'data1/train_label_model1.csv')
save_filtered_data(
    X_test_scaled1, y_test_model1_onehot, 
    'data1/test_sample_model1.csv', 
    'data1/test_label_model1.csv')

# %%
# Apply the filter to the train and test sets
X_train_model2, y_train_model2 = filter_data_for_X(y_train, X_train, [4, 5, 6])
X_test_model2, y_test_model2 = filter_data_for_X(y_test, X_test, [4, 5, 6])

X_train_scaled2 = np.apply_along_axis(
    lambda row: scaler.fit_transform(row.reshape(-1, 1)).flatten(), axis=1, arr=X_train_model2)
X_test_scaled2 = np.apply_along_axis(
    lambda row: scaler.fit_transform(row.reshape(-1, 1)).flatten(), axis=1, arr=X_test_model2)

# Apply the transformation to the labels
y_train_model2 = transform_labels_model(y_train_model2, [4, 5, 6], [1, 2, 3])
y_test_model2 = transform_labels_model(y_test_model2, [4, 5, 6], [1, 2, 3])

# Apply one-hot encoding to the labels for Model 2
y_train_model2_onehot = to_one_hot(y_train_model2, num_classes=3)
y_test_model2_onehot = to_one_hot(y_test_model2, num_classes=3)

save_filtered_data(
    X_train_scaled2, y_train_model2_onehot, 
    'data1/train_sample_model2.csv', 
    'data1/train_label_model2.csv')
save_filtered_data(
    X_test_scaled2, y_test_model2_onehot, 
    'data1/test_sample_model2.csv', 
    'data1/test_label_model2.csv')

# %%
# Apply the filter to the train and test sets
X_train_model3, y_train_model3 = filter_data_for_X(y_train, X_train, [7, 8, 9])
X_test_model3, y_test_model3 = filter_data_for_X(y_test, X_test, [7, 8, 9])

X_train_scaled3 = np.apply_along_axis(
    lambda row: scaler.fit_transform(row.reshape(-1, 1)).flatten(), axis=1, arr=X_train_model3)
X_test_scaled3 = np.apply_along_axis(
    lambda row: scaler.fit_transform(row.reshape(-1, 1)).flatten(), axis=1, arr=X_test_model3)

# Apply the transformation to the labels
y_train_model3 = transform_labels_model(y_train_model3, [7, 8, 9], [1, 2, 3])
y_test_model3 = transform_labels_model(y_test_model3, [7, 8, 9], [1, 2, 3])

# Apply one-hot encoding to the labels for Model 2
y_train_model3_onehot = to_one_hot(y_train_model3, num_classes=3)
y_test_model3_onehot = to_one_hot(y_test_model3, num_classes=3)

save_filtered_data(
    X_train_scaled3, y_train_model3_onehot, 
    'data1/train_sample_model3.csv', 
    'data1/train_label_model3.csv')
save_filtered_data(
    X_test_scaled3, y_test_model3_onehot, 
    'data1/test_sample_model3.csv', 
    'data1/test_label_model3.csv')

# %%
# Load the data from L1_8000rpm_data/ folder
X_train = pd.read_csv('data1/train_sample_model.csv').values
X_test = pd.read_csv('data1/test_sample_model.csv').values
y_train = pd.read_csv('data1/train_label_model.csv').values
y_test = pd.read_csv('data1/test_label_model.csv').values

# Convert data to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1).to(device)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1).to(device)
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

# %%
# Load the data from L1_8000rpm_data/ folder
X_train1 = pd.read_csv('data1/train_sample_model1.csv').values
X_test1 = pd.read_csv('data1/test_sample_model1.csv').values
y_train1 = pd.read_csv('data1/train_label_model1.csv').values
y_test1 = pd.read_csv('data1/test_label_model1.csv').values

# Convert data to PyTorch tensors
X_train1 = torch.tensor(X_train1, dtype=torch.float32).unsqueeze(1).to(device)
X_test1 = torch.tensor(X_test1, dtype=torch.float32).unsqueeze(1).to(device)
y_train1 = torch.tensor(y_train1, dtype=torch.long).to(device)
y_test1 = torch.tensor(y_test1, dtype=torch.long).to(device)

# %%
# Load the data from L1_8000rpm_data/ folder
X_train2 = pd.read_csv('data1/train_sample_model2.csv').values
X_test2 = pd.read_csv('data1/test_sample_model2.csv').values
y_train2 = pd.read_csv('data1/train_label_model2.csv').values
y_test2 = pd.read_csv('data1/test_label_model2.csv').values

# Convert data to PyTorch tensors
X_train2 = torch.tensor(X_train2, dtype=torch.float32).unsqueeze(1).to(device)
X_test2 = torch.tensor(X_test2, dtype=torch.float32).unsqueeze(1).to(device)
y_train2 = torch.tensor(y_train2, dtype=torch.long).to(device)
y_test2 = torch.tensor(y_test2, dtype=torch.long).to(device)

# %%
# Load the data from L1_8000rpm_data/ folder
X_train3 = pd.read_csv('data1/train_sample_model3.csv').values
X_test3 = pd.read_csv('data1/test_sample_model3.csv').values
y_train3 = pd.read_csv('data1/train_label_model3.csv').values
y_test3 = pd.read_csv('data1/test_label_model3.csv').values

# Convert data to PyTorch tensors
X_train3 = torch.tensor(X_train3, dtype=torch.float32).unsqueeze(1).to(device)
X_test3 = torch.tensor(X_test3, dtype=torch.float32).unsqueeze(1).to(device)
y_train3 = torch.tensor(y_train3, dtype=torch.long).to(device)
y_test3 = torch.tensor(y_test3, dtype=torch.long).to(device)

# %%
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
# Create DataLoader for batching
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Instantiate model, loss, and optimizer
from model import CNN, sCNN
learning_rate = 0.00001
model = CNN(num_class=3, dropout_rate=0.4, kernel_size=3).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Train the model
num_epochs = 50
history = {'loss': [], 'accuracy': [], 'val_accuracy': []}
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels.argmax(dim=1))
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels.argmax(dim=1)).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_accuracy = correct / total
    history['loss'].append(epoch_loss)
    history['accuracy'].append(epoch_accuracy)
    
    model.eval()  # Set the model to evaluation mode
    val_correct = 0
    val_total = 0
    with torch.no_grad():  # No need to compute gradients for validation
        for inputs, labels in test_loader:  # Assuming you have a validation data loader
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            val_correct += (predicted == labels.argmax(dim=1)).sum().item()
            val_total += labels.size(0)

    val_accuracy = val_correct / val_total
    history['val_accuracy'].append(val_accuracy)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/50, Loss: 0.5154, Accuracy: 0.8267, Validation Accuracy: 1.0000
# Epoch 2/50, Loss: 0.1173, Accuracy: 0.9833, Validation Accuracy: 1.0000
# Epoch 3/50, Loss: 0.0676, Accuracy: 0.9856, Validation Accuracy: 1.0000
# Epoch 4/50, Loss: 0.0495, Accuracy: 0.9883, Validation Accuracy: 1.0000
# Epoch 5/50, Loss: 0.0334, Accuracy: 0.9922, Validation Accuracy: 1.0000
# Epoch 6/50, Loss: 0.0289, Accuracy: 0.9944, Validation Accuracy: 1.0000
# Epoch 7/50, Loss: 0.0215, Accuracy: 0.9956, Validation Accuracy: 1.0000
# Epoch 8/50, Loss: 0.0177, Accuracy: 0.9956, Validation Accuracy: 1.0000
# Epoch 9/50, Loss: 0.0153, Accuracy: 0.9961, Validation Accuracy: 1.0000
# Epoch 10/50, Loss: 0.0128, Accuracy: 0.9961, Validation Accuracy: 1.0000
# Epoch 11/50, Loss: 0.0169, Accuracy: 0.9933, Validation Accuracy: 1.0000
# Epoch 12/50, Loss: 0.0129, Accuracy: 0.9961, Validation Accuracy: 1.0000
# Epoch 13/50, Loss: 0.0085, Accuracy: 0.9989, Validation Accuracy: 1.0000
# ...

# %%
# Create DataLoader for batching
train_dataset1 = TensorDataset(X_train1, y_train1)
test_dataset1 = TensorDataset(X_test1, y_test1)
train_loader1 = DataLoader(train_dataset1, batch_size=32, shuffle=True)
test_loader1 = DataLoader(test_dataset1, batch_size=32, shuffle=False)

# %%
learning_rate = 0.00001
model1 = CNN(num_class=3, dropout_rate=0.4, kernel_size=3).to(device)
criterion1 = nn.CrossEntropyLoss()
optimizer1 = optim.Adam(model1.parameters(), lr=learning_rate)

# %%
# Train the model
num_epochs = 50
history1 = {'loss': [], 'accuracy': [], 'val_accuracy': []}
for epoch in range(num_epochs):
    model1.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader1:
        optimizer1.zero_grad()
        outputs = model1(inputs)
        loss = criterion1(outputs, labels.argmax(dim=1))
        loss.backward()
        optimizer1.step()

        running_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels.argmax(dim=1)).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_accuracy = correct / total
    history1['loss'].append(epoch_loss)
    history1['accuracy'].append(epoch_accuracy)
    
    model1.eval()  # Set the model to evaluation mode
    val_correct = 0
    val_total = 0
    with torch.no_grad():  # No need to compute gradients for validation
        for inputs, labels in test_loader1:  # Assuming you have a validation data loader
            outputs = model1(inputs)
            _, predicted = torch.max(outputs, 1)
            val_correct += (predicted == labels.argmax(dim=1)).sum().item()
            val_total += labels.size(0)

    val_accuracy = val_correct / val_total
    history1['val_accuracy'].append(val_accuracy)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/50, Loss: 1.0648, Accuracy: 0.4517, Validation Accuracy: 0.3333
# Epoch 2/50, Loss: 0.9019, Accuracy: 0.6917, Validation Accuracy: 0.6800
# Epoch 3/50, Loss: 0.6792, Accuracy: 0.8067, Validation Accuracy: 0.9400
# Epoch 4/50, Loss: 0.5124, Accuracy: 0.8783, Validation Accuracy: 0.9467
# Epoch 5/50, Loss: 0.4270, Accuracy: 0.8883, Validation Accuracy: 0.9200
# Epoch 6/50, Loss: 0.3415, Accuracy: 0.9267, Validation Accuracy: 0.9267
# Epoch 7/50, Loss: 0.3094, Accuracy: 0.9267, Validation Accuracy: 0.9333
# Epoch 8/50, Loss: 0.2689, Accuracy: 0.9283, Validation Accuracy: 0.9333
# Epoch 9/50, Loss: 0.2251, Accuracy: 0.9467, Validation Accuracy: 0.9333
# Epoch 10/50, Loss: 0.1849, Accuracy: 0.9667, Validation Accuracy: 0.9533
# Epoch 11/50, Loss: 0.1818, Accuracy: 0.9617, Validation Accuracy: 0.9533
# Epoch 12/50, Loss: 0.1455, Accuracy: 0.9683, Validation Accuracy: 0.9533
# Epoch 13/50, Loss: 0.1433, Accuracy: 0.9683, Validation Accuracy: 0.9467
# ...

# %%
# Create DataLoader for batching
train_dataset2 = TensorDataset(X_train2, y_train2)
test_dataset2 = TensorDataset(X_test2, y_test2)
train_loader2 = DataLoader(train_dataset2, batch_size=32, shuffle=True)
test_loader2 = DataLoader(test_dataset2, batch_size=32, shuffle=False)

# %%
learning_rate = 0.00001
model2 = CNN(num_class=3, dropout_rate=0.4, kernel_size=3).to(device)
criterion2 = nn.CrossEntropyLoss()
optimizer2 = optim.Adam(model2.parameters(), lr=learning_rate)

# %%
# Train the model
num_epochs = 50
history2 = {'loss': [], 'accuracy': [], 'val_accuracy': []}
for epoch in range(num_epochs):
    model2.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader2:
        optimizer2.zero_grad()
        outputs = model2(inputs)
        loss = criterion2(outputs, labels.argmax(dim=1))
        loss.backward()
        optimizer2.step()

        running_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels.argmax(dim=1)).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_accuracy = correct / total
    history2['loss'].append(epoch_loss)
    history2['accuracy'].append(epoch_accuracy)
    
    model2.eval()  # Set the model to evaluation mode
    val_correct = 0
    val_total = 0
    with torch.no_grad():  # No need to compute gradients for validation
        for inputs, labels in test_loader2:  # Assuming you have a validation data loader
            outputs = model2(inputs)
            _, predicted = torch.max(outputs, 1)
            val_correct += (predicted == labels.argmax(dim=1)).sum().item()
            val_total += labels.size(0)

    val_accuracy = val_correct / val_total
    history2['val_accuracy'].append(val_accuracy)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/50, Loss: 1.0949, Accuracy: 0.3633, Validation Accuracy: 0.4133
# Epoch 2/50, Loss: 1.0551, Accuracy: 0.4650, Validation Accuracy: 0.5133
# Epoch 3/50, Loss: 0.9851, Accuracy: 0.5583, Validation Accuracy: 0.8333
# Epoch 4/50, Loss: 0.9097, Accuracy: 0.6333, Validation Accuracy: 0.7733
# Epoch 5/50, Loss: 0.8116, Accuracy: 0.7083, Validation Accuracy: 0.8467
# Epoch 6/50, Loss: 0.7481, Accuracy: 0.7083, Validation Accuracy: 0.8533
# Epoch 7/50, Loss: 0.6606, Accuracy: 0.7850, Validation Accuracy: 0.8600
# Epoch 8/50, Loss: 0.5969, Accuracy: 0.8050, Validation Accuracy: 0.8667
# Epoch 9/50, Loss: 0.5213, Accuracy: 0.8383, Validation Accuracy: 0.8667
# Epoch 10/50, Loss: 0.4817, Accuracy: 0.8433, Validation Accuracy: 0.8667
# Epoch 11/50, Loss: 0.4253, Accuracy: 0.8933, Validation Accuracy: 0.8667
# Epoch 12/50, Loss: 0.3720, Accuracy: 0.8933, Validation Accuracy: 0.8733
# Epoch 13/50, Loss: 0.3283, Accuracy: 0.9300, Validation Accuracy: 0.8800
# ...

# %%
# Create DataLoader for batching
train_dataset3 = TensorDataset(X_train3, y_train3)
test_dataset3 = TensorDataset(X_test3, y_test3)
train_loader3 = DataLoader(train_dataset3, batch_size=32, shuffle=True)
test_loader3 = DataLoader(test_dataset3, batch_size=32, shuffle=False)

# %%
learning_rate = 0.00001
model3 = CNN(num_class=3, dropout_rate=0.4, kernel_size=3).to(device)
criterion3 = nn.CrossEntropyLoss()
optimizer3 = optim.Adam(model3.parameters(), lr=learning_rate)

# %%
# Train the model
num_epochs = 50
history3 = {'loss': [], 'accuracy': [], 'val_accuracy': []}
for epoch in range(num_epochs):
    model3.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in train_loader3:
        optimizer3.zero_grad()
        outputs = model3(inputs)
        loss = criterion3(outputs, labels.argmax(dim=1))
        loss.backward()
        optimizer3.step()

        running_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels.argmax(dim=1)).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_accuracy = correct / total
    history3['loss'].append(epoch_loss)
    history3['accuracy'].append(epoch_accuracy)
    
    model3.eval()  # Set the model to evaluation mode
    val_correct = 0
    val_total = 0
    with torch.no_grad():  # No need to compute gradients for validation
        for inputs, labels in test_loader3:  # Assuming you have a validation data loader
            outputs = model3(inputs)
            _, predicted = torch.max(outputs, 1)
            val_correct += (predicted == labels.argmax(dim=1)).sum().item()
            val_total += labels.size(0)

    val_accuracy = val_correct / val_total
    history3['val_accuracy'].append(val_accuracy)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/50, Loss: 1.0873, Accuracy: 0.3917, Validation Accuracy: 0.3467
# Epoch 2/50, Loss: 1.0417, Accuracy: 0.4583, Validation Accuracy: 0.7000
# Epoch 3/50, Loss: 0.9816, Accuracy: 0.5567, Validation Accuracy: 0.6933
# Epoch 4/50, Loss: 0.9104, Accuracy: 0.6367, Validation Accuracy: 0.7267
# Epoch 5/50, Loss: 0.8388, Accuracy: 0.6567, Validation Accuracy: 0.7400
# Epoch 6/50, Loss: 0.7567, Accuracy: 0.7100, Validation Accuracy: 0.7667
# Epoch 7/50, Loss: 0.7151, Accuracy: 0.7417, Validation Accuracy: 0.7600
# Epoch 8/50, Loss: 0.6622, Accuracy: 0.7617, Validation Accuracy: 0.7733
# Epoch 9/50, Loss: 0.5829, Accuracy: 0.8183, Validation Accuracy: 0.7667
# Epoch 10/50, Loss: 0.5223, Accuracy: 0.8567, Validation Accuracy: 0.8533
# Epoch 11/50, Loss: 0.4852, Accuracy: 0.8650, Validation Accuracy: 0.8267
# Epoch 12/50, Loss: 0.4422, Accuracy: 0.8767, Validation Accuracy: 0.8267
# Epoch 13/50, Loss: 0.4174, Accuracy: 0.8917, Validation Accuracy: 0.8400
# ...

# %%
# Load the data from L1_8000rpm_data/ folder
y_train = pd.read_csv('8000rpm_data_z-score/train_label.csv').values
y_test = pd.read_csv('8000rpm_data_z-score/test_label.csv').values

# Convert data to PyTorch tensors
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

# %%
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix

def convert_predictions_model2(predictions):
    prediction_map = {0: 3, 1: 4, 2: 5}
    return np.array([prediction_map[pred.item()] for pred in predictions])

def convert_predictions_model3(predictions):
    prediction_map = {0: 6, 1: 7, 2: 8}
    return np.array([prediction_map[pred.item()] for pred in predictions])

# Test Model 1 on X_test
model1.eval()
y_pred_model = model(X_test).argmax(dim=1).cpu().numpy()

mask1 = (y_pred_model == 0)
X_1 = X_test[mask1]
model1.eval()
y_pred_model1 = model1(X_1).argmax(dim=1).cpu().numpy()

mask2 = (y_pred_model == 1)
X_2 = X_test[mask2]
model2.eval()
y_pred_model2 = model2(X_2).argmax(dim=1).cpu().numpy()
y_pred_model2 = convert_predictions_model2(y_pred_model2)

mask3 = (y_pred_model == 2)
X_3 = X_test[mask3]
model3.eval()
y_pred_model3 = model3(X_3).argmax(dim=1).cpu().numpy()
y_pred_model3 = convert_predictions_model3(y_pred_model3)

y_pred_model[mask1] = y_pred_model1
y_pred_model[mask2] = y_pred_model2
y_pred_model[mask3] = y_pred_model3
y_test_numeric = y_test.cpu().numpy()

def one_hot_to_single_label(y):
    return np.argmax(y, axis=1)  # Get the index of the max value in each row

# If y_test or y_pred_model1 are one-hot encoded, convert them to single labels
y_test_single = one_hot_to_single_label(y_test_numeric)
accuracy = accuracy_score(y_test_single, y_pred_model)
print(f"Overall Accuracy: {accuracy * 100:.2f}%")

cm = confusion_matrix(y_test_single, y_pred_model)
print("Confusion Matrix:")
print(cm)

# 绘制混淆矩阵
plt.matshow(cm, cmap='Blues')
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(x=j, y=i, s=cm[i, j], va='center', ha='center')

plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Overall Accuracy: 93.11%
# Confusion Matrix:
# [[48  1  1  0  0  0  0  0  0]
#  [ 2 48  0  0  0  0  0  0  0]
#  [ 2  0 48  0  0  0  0  0  0]
#  [ 0  0  0 49  1  0  0  0  0]
#  [ 0  0  0  3 44  3  0  0  0]
#  [ 0  0  0  1  7 42  0  0  0]
#  [ 0  0  0  0  0  0 49  1  0]
#  [ 0  0  0  0  0  0  0 44  6]
#  [ 0  0  0  0  0  0  0  3 47]]
